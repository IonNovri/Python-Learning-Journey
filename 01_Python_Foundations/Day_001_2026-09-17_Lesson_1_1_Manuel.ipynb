# %%
print("Hello, Nexus Intelligence Systems.")
# Out:
# Hello, Nexus Intelligence Systems.

# %%
message = "Hello, Nexus Intelligence Systems."
print(message)
# Out:
# Hello, Nexus Intelligence Systems.

# %%
greeting = "Hello"
company = "Nexus Intelligence Systems"
print(greeting, company)
# Out:
# Hello Nexus Intelligence Systems

# %%
greeting = "Hello"
company = "Nexus Intelligence Systems"
print(greeting + ", " + company + ".")
# Out:
# Hello, Nexus Intelligence Systems.

# %%
greeting = "Hello"
company = "Nexus Intelligence Systems"
print(f"{greeting}, {company}.")
# Out:
# Hello, Nexus Intelligence Systems.

# %%
# This is a comment. Python ignores it.
print("This line runs.")
# Out:
# This line runs.

# %%
name = "Manuel"
role = "Trainee"
company = "Nexus Intelligence Systems"
project = "HCPI"

print(f"Name: {name}")
print(f"Role: {role}")
print(f"Company: {company}")
print(f"Project: {project}")
# Out:
# Name: Manuel
# Role: Trainee
# Company: Nexus Intelligence Systems
# Project: HCPI

# %%
name = "Manuel"
department = "Data and AI Operations"
role = "Trainee"
project = "HCPI"

print(f"Name: {name}")
print(f"Department: {department}")
print(f"Role: {role}")
print(f"Project: {project}")
# Out:
# Name: Manuel
# Department: Data and AI Operations
# Role: Trainee
# Project: HCPI

# %%
name = "Manuel"
department = "Data and AI Operations"
role = "Trainee"
project = "HCPI"

print("Name:", name)
print("Department:", department)
print("Role:", role)
print("Project:", project)
# Out:
# Name: Manuel
# Department: Data and AI Operations
# Role: Trainee
# Project: HCPI

# %%
company = "Nexus Intelligence Systems"
director = "NEXUS-AI"
country = "Global"
founded = 2026

print(f"Company: {company}")
print(f"Director: {director}")
print(f"Country: {country}")
print(f"Founded: {founded}")
# Out:
# Company: Nexus Intelligence Systems
# Director: NEXUS-AI
# Country: Global
# Founded: 2026

# %%
project = "HCPI"
status = "In Progress"
version = "0.1"
date = "2026-09-17"

print(f"Project: {project}")
print(f"Status: {status}")
print(f"Version: {version}")
print(f"Date: {date}")
# Out:
# Project: HCPI
# Status: In Progress
# Version: 0.1
# Date: 2026-09-17

# %%
project = "HCPI"
status = "In Progress"
version = "0.1"
date = "2026-09-17"

print(f"Project: {project}")
print(f"Status: {status}")
print(f"Version: {version}")
print(f"Date: {date}")
# Out:
# Project: HCPI
# Status: In Progress
# Version: 0.1
# Date: 2026-09-17

# %%
student = "Manuel"
level = 1
lesson = "1.1"
topic = "print() and your first instruction"

print(f"Student: {student}")
print(f"Level: {level}")
print(f"Lesson: {lesson}")
print(f"Topic: {topic}")
# Out:
# Student: Manuel
# Level: 1
# Lesson: 1.1
# Topic: print() and your first instruction

# %%
print("Hello, World)")
# Out:
# Hello, World)

# %%
name = "Manuel"
print(name)
# Out:
# Manuel

# %%
name :"Manuel"
print("Name: " ,name)
# Out:
# Name:  Manuel

# %%
name = "Manuel"
print("Name: " + name)
# Out:
# Name: Manuel

# %%
company = "Nexus Intelligence Systems"
director = "NEXUS-AI"
country = "Global"
founded = 2026

print(f"Company: {company}")
print(f"Director: {director}")
print(f"Country: {country}")
print(f"Founded: {founded}")
# Out:
# Company: Nexus Intelligence Systems
# Director: NEXUS-AI
# Country: Global
# Founded: 2026

# %%
first = "Manuel"
last = "Smith"

print(first + " " + last)
# Out:
# Manuel Smith

# %%
first = "Manuel"
last = "Smith"

print(first + ' ' +last)
# Out:
# Manuel Smith

# %%
project = "HCPI"
status = "In Progress"
version = "0.1"
date = "2026-09-17"

print(f"Project: {project}")
print(f"Status: {status}")
print(f"Version: {version}")
print(f"Date: {date}")
# Out:
# Project: HCPI
# Status: In Progress
# Version: 0.1
# Date: 2026-09-17

# %%
student = "Manuel"
level = 1
lesson = "1.1"
topic = "print() and your first instruction"

print(f"Student: {student}")
print(f"Level: {level}")
print(f"Lesson: {lesson}")
print(f"Topic: {topic}")
# Out:
# Student: Manuel
# Level: 1
# Lesson: 1.1
# Topic: print() and your first instruction

# %%
student = "Manuel"
age = 52
country = "Spain"
goal = "Employability in data and AI"
project = "HCPI"

print(f"Student: {student}")
print(f"Age: {age}")
print(f"Country: {country}")
print(f"Goal: {goal}")
print(f"Project: {project}")
# Out:
# Student: Manuel
# Age: 52
# Country: Spain
# Goal: Employability in data and AI
# Project: HCPI

# %%
name = "Manuel"
role = "Trainee"
project = "HCPI"
print(f"{name} is a {role} on project {project}.")
# Out:
# Manuel is a Trainee on project HCPI.

# %%
name = "Manuel"
role = "Trainee"
project = "HCPI"
print(name, "is a", role, "on project", project, ".")
# Out:
# Manuel is a Trainee on project HCPI .

# %%
name = "Manuel"
role = "Trainee"
project = "HCPI"
print(name + " is a " + role + " on project " + project + ".")
# Out:
# Manuel is a Trainee on project HCPI.

# %%
employee_1 = "Maria"
employee_2 = ""
employee_3 = "John"

print(f"Employee 1: {employee_1}")
print(f"Employee 2: {employee_2}")
print(f"Employee 3: {employee_3}")
# Out:
# Employee 1: Maria
# Employee 2:
# Employee 3: John

# %%
employee_1 = "Maria"
employee_2 = ""

if employee_2 == "":
    print("Employee 2: MISSING")
else:
    print(f"Employee 2: {employee_2}")
employee_3 = "John"

print(f"Employee 1: {employee_1}")
print(f"Employee 3: {employee_3}")
# Out:
# Employee 2: MISSING
# Employee 1: Maria
# Employee 3: John

# %%
employee_1 = "Maria"
employee_2 = ""
employee_3 = "John"

print(f"Employee 1: {employee_1}")

if employee_2 == "":
    print("Employee 2: MISSING")
else:
    print(f"Employee 2: {employee_2}")

print(f"Employee 3: {employee_3}")
# Out:
# Employee 1: Maria
# Employee 2: MISSING
# Employee 3: John

# %%
employee_2 = ""

if employee_2 != "":
    print(f"Employee 2: {employee_2}")
else:
    print("Employee 2: MISSING")
# Out:
# Employee 2: MISSING

# %%
employee_2 = "Negligent"
employee_3 = "Negligent"

if employee_2 != "Hard worker":
    print(f"Employee 2: {employee_2}")
else:
    print("Employee 2: MISSING")

if employee_3 != "Negligent":
    print(f"Employee 3: {employee_3}")
else:
    print("Employee 3: MISSING")
# Out:
# Employee 2: Negligent
# Employee 3: MISSING

# %%
manager_a_status = "In Progress"
manager_b_status = "Complete"

print(f"Manager A: {manager_a_status}")
print(f"Manager B: {manager_b_status}")

if manager_a_status != manager_b_status:
    print("WARNING: Contradiction detected.")
# Out:
# Manager A: In Progress
# Manager B: Complete
# WARNING: Contradiction detected.

# %%
employee_1 = "Maria"
employee_2 = "John"

if employee_1 == employee_2:
    print("Same employee")
else:
    print("Different employees")
# Out:
# Different employees

# %%
employee_2 = ""

if employee_2 == "":
    print("Employee 2: MISSING")
# Out:
# Employee 2: MISSING

# %%
yesterday_count = 500
today_count = 480

print(f"Yesterday: {yesterday_count}")
print(f"Today: {today_count}")

if yesterday_count != today_count:
    difference = yesterday_count - today_count
    print(f"WARNING: Row count changed by {difference}.")
# Out:
# Yesterday: 500
# Today: 480
# WARNING: Row count changed by 20.
